# %% [markdown]
# #Importing library

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ybifoundation/Dataset/main/Titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# #Missing Values

# %%
df.isna().sum()    #gives count of missing values.
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# #Remove missing values

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# #Sampling gives random data

# %%
df.sample(5)
# Out:
#       pclass  survived                                 name     sex   age  \
# 862        3         1         Hellstrom, Miss. Hilda Maria  female  22.0
# 952        3         0       Larsson-Rondberg, Mr. Edvard A    male  22.0
# 1222       3         0                  Stankovic, Mr. Ivan    male  33.0
# 1135       3         0                Radeff, Mr. Alexander    male   NaN
# 573        2         1  Troutt, Miss. Edwina Celia "Winnie"  female  27.0
#
#       sibsp  parch  ticket     fare cabin embarked boat  body  \
# 862       0      0    7548   8.9625   NaN        S    C   NaN
# 952       0      0  347065   7.7750   NaN        S  NaN   NaN
# 1222      0      0  349239   8.6625   NaN        C  NaN   NaN
# 1135      0      0  349223   7.8958   NaN        S  NaN   NaN
# 573       0      0   34218  10.5000  E101        S   16   NaN
#
#                           home.dest
# 862                             NaN
# 952                             NaN
# ...

# %% [markdown]
# #Multiple Column

# %%
df[["name","age","sex"]]
# Out:
#                                                  name    age     sex
# 0                       Allen, Miss. Elisabeth Walton  29.00  female
# 1                      Allison, Master. Hudson Trevor   0.92    male
# 2                        Allison, Miss. Helen Loraine   2.00  female
# 3                Allison, Mr. Hudson Joshua Creighton  30.00    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00  female
# ...                                               ...    ...     ...
# 1304                             Zabour, Miss. Hileni  14.50  female
# 1305                            Zabour, Miss. Thamine    NaN  female
# 1306                        Zakarian, Mr. Mapriededer  26.50    male
# 1307                              Zakarian, Mr. Ortin  27.00    male
# 1308                               Zimmerman, Mr. Leo  29.00    male
#
# [1309 rows x 3 columns]

# %%
df['age'].fillna(00)
df['fare'].fillna(00)
df['cabin'].fillna("NONE")
df['boat'].fillna(00)
df['body'].fillna(00)
df['home.dest'].fillna("NONE")
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                               NONE
# 1305                               NONE
# 1306                               NONE
# 1307                               NONE
# 1308                               NONE
# Name: home.dest, Length: 1309, dtype: object

# %% [markdown]
# #LOC

# %%
df.loc[0:2,:]
print("\n\n----------------------------------------------\n\n")
df.loc[10:15 , ['survived','name','sex','ticket','fare','cabin']]
# Out:
# ----------------------------------------------
#     survived                                               name     sex  \
# 10         0                             Astor, Col. John Jacob    male
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# 12         1                      Aubart, Mme. Leontine Pauline  female
# 13         1                       Barber, Miss. Ellen "Nellie"  female
# 14         1               Barkworth, Mr. Algernon Henry Wilson    male
# 15         0                                Baumann, Mr. John D    male
#
#       ticket     fare    cabin
# 10  PC 17757  227.525  C62 C64
# 11  PC 17757  227.525  C62 C64
# 12  PC 17477   69.300      B35
# 13     19877   78.850      NaN
# 14     27042   30.000      A23
# 15  PC 17318   25.925      NaN

# %%
df[df['age']<15]
# Out:
#       pclass  survived                                  name     sex    age  \
# 1          1         1        Allison, Master. Hudson Trevor    male   0.92
# 2          1         0          Allison, Miss. Helen Loraine  female   2.00
# 54         1         1   Carter, Master. William Thornton II    male  11.00
# 55         1         1             Carter, Miss. Lucile Polk  female  14.00
# 94         1         1             Dodge, Master. Washington    male   4.00
# ...      ...       ...                                   ...     ...    ...
# 1257       3         1            Touma, Miss. Maria Youssef  female   9.00
# 1263       3         0     van Billiard, Master. Walter John    male  11.50
# 1265       3         0             Van Impe, Miss. Catharina  female  10.00
# 1279       3         0  Vestrom, Miss. Hulda Amanda Adolfina  female  14.00
# 1304       3         0                  Zabour, Miss. Hileni  female  14.50
#
# ...

# %%
df[df['sex']=="male"]
# Out:
#       pclass  survived                                  name   sex    age  \
# 1          1         1        Allison, Master. Hudson Trevor  male   0.92
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male  30.00
# 5          1         1                   Anderson, Mr. Harry  male  48.00
# 7          1         0                Andrews, Mr. Thomas Jr  male  39.00
# 9          1         0               Artagaveytia, Mr. Ramon  male  71.00
# ...      ...       ...                                   ...   ...    ...
# 1302       3         0                     Yousif, Mr. Wazli  male    NaN
# 1303       3         0                 Yousseff, Mr. Gerious  male    NaN
# 1306       3         0             Zakarian, Mr. Mapriededer  male  26.50
# 1307       3         0                   Zakarian, Mr. Ortin  male  27.00
# 1308       3         0                    Zimmerman, Mr. Leo  male  29.00
#
#       sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
df[df['sex']=="female"]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df[df['sex']=="female"].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# pclass                                                   1004
# survived                                                  339
# name        Allen, Miss. Elisabeth WaltonAllison, Miss. He...
# sex         femalefemalefemalefemalefemalefemalefemalefema...
# age                                                  11130.59
# sibsp                                                     304
# parch                                                     295
# ticket      241601137811137811350211769PC 17757PC 17477198...
# fare                                                21528.313
# body                                                   1333.0
# dtype: object

# %%
#df['SEX_short']=df['sex'].replace({"male:"M,"female":"F"})

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 10
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
