# %% [markdown]
# #Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Titanic.csv')

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
df.describe(include='all')    #if you wanna include non statitical data too

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.shape
# Out:
# (1309, 14)

# %%
len(df)
# Out:
# 1309

# %%
#  random sample
df.sample()
# Out:
#       pclass  survived                   name   sex  age  sibsp  parch ticket  \
# 1241       3         0  Thomas, Mr. Charles P  male  NaN      1      0   2621
#
#         fare cabin embarked boat  body home.dest
# 1241  6.4375   NaN        C  NaN   NaN       NaN

# %%
df.corr()
# as age increases the survival chance decreases, shown in corr
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055512 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055512  1.000000 -0.243699 -0.150917  0.178740  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178740  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
df['age'].nlargest(5)
# Out:
# 14      80.0
# 61      76.0
# 1235    74.0
# 9       71.0
# 135     71.0
# Name: age, dtype: float64

# %%
df['fare'].nsmallest(5)
# Out:
# 7      0.0
# 70     0.0
# 125    0.0
# 150    0.0
# 170    0.0
# Name: fare, dtype: float64

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# pclass        2.294882
# survived      0.381971
# age          29.881138
# sibsp         0.498854
# parch         0.385027
# fare         33.295479
# body        160.809917
# dtype: float64

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# pclass        3.0000
# survived      0.0000
# age          28.0000
# sibsp         0.0000
# parch         0.0000
# fare         14.4542
# body        155.0000
# dtype: float64

# %%
df.mode()
# Out:
#      pclass  survived                  name   sex   age  sibsp  parch  \
# 0       3.0       0.0  Connolly, Miss. Kate  male  24.0    0.0    0.0
# 1       NaN       NaN      Kelly, Mr. James   NaN   NaN    NaN    NaN
# 2       NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# 3       NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# 4       NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# ..      ...       ...                   ...   ...   ...    ...    ...
# 116     NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# 117     NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# 118     NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# 119     NaN       NaN                   NaN   NaN   NaN    NaN    NaN
# 120     NaN       NaN                   NaN   NaN   NaN    NaN    NaN
#
#        ticket  fare        cabin embarked boat   body     home.dest
# ...

# %%
df['age'].agg(['mean','min','max'])
# Out:
# mean    29.881138
# min      0.170000
# max     80.000000
# Name: age, dtype: float64

# %%
x = df[['age','sex','fare','name']]
print(x)
# Out:
#         age     sex      fare                                             name
# 0     29.00  female  211.3375                    Allen, Miss. Elisabeth Walton
# 1      0.92    male  151.5500                   Allison, Master. Hudson Trevor
# 2      2.00  female  151.5500                     Allison, Miss. Helen Loraine
# 3     30.00    male  151.5500             Allison, Mr. Hudson Joshua Creighton
# 4     25.00  female  151.5500  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...     ...     ...       ...                                              ...
# 1304  14.50  female   14.4542                             Zabour, Miss. Hileni
# 1305    NaN  female   14.4542                            Zabour, Miss. Thamine
# 1306  26.50    male    7.2250                        Zakarian, Mr. Mapriededer
# 1307  27.00    male    7.2250                              Zakarian, Mr. Ortin
# 1308  29.00    male    7.8750                               Zimmerman, Mr. Leo
#
# [1309 rows x 4 columns]

# %%
df[['survived']]
# Out:
#       survived
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0
# ...        ...
# 1304         0
# 1305         0
# 1306         0
# 1307         0
# 1308         0
#
# [1309 rows x 1 columns]

# %%
df['survived']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64

# %%
df['fare'].unique()
# Out:
# array([211.3375, 151.55  ,  26.55  ,  77.9583,   0.    ,  51.4792,
#         49.5042, 227.525 ,  69.3   ,  78.85  ,  30.    ,  25.925 ,
#        247.5208,  76.2917,  75.2417,  52.5542, 221.7792,  26.    ,
#         91.0792, 135.6333,  35.5   ,  31.    , 164.8667, 262.375 ,
#         55.    ,  30.5   ,  50.4958,  39.6   ,  27.7208, 134.5   ,
#         26.2875,  27.4458, 512.3292,   5.    ,  47.1   , 120.    ,
#         61.175 ,  53.1   ,  86.5   ,  29.7   , 136.7792,  52.    ,
#         25.5875,  83.1583,  25.7   ,  71.    ,  71.2833,  57.    ,
#         81.8583, 106.425 ,  56.9292,  78.2667,  31.6792,  31.6833,
#        110.8833,  26.3875,  27.75  , 263.    , 133.65  ,  49.5   ,
#         79.2   ,  38.5   , 211.5   ,  59.4   ,  89.1042,  34.6542,
#         28.5   , 153.4625,  63.3583,  55.4417,  76.7292,  42.4   ,
#         83.475 ,  93.5   ,  42.5   ,  51.8625,  50.    ,  57.9792,
#         90.    ,  30.6958,  80.    ,  28.7125,  25.9292,  39.4   ,
# ...

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df.replace({'sex':{'female':1,'male':0}})
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    1
# 1          1         1                   Allison, Master. Hudson Trevor    0
# 2          1         0                     Allison, Miss. Helen Loraine    1
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    1
# 1305       3         0                            Zabour, Miss. Thamine    1
# 1306       3         0                        Zakarian, Mr. Mapriededer    0
# 1307       3         0                              Zakarian, Mr. Ortin    0
# 1308       3         0                               Zimmerman, Mr. Leo    0
#
# ...

# %%
#df.set_index('cabin') #it'll set cabin as index... indexing will start as per cabin alphabet order

# %%
#reindex the index
df.reindex()

# %%
#change the name of col
df.rename(columns = {'sex':'gender'})
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.sort_index(axis={0:'first_row',1:'second_row'})

# %%
df.sort_values(by='name')
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
# ...

# %%
df.sort_values(by=['name','pclass'])
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
# ...

# %%
df[(df['age']<15) & (df['sex']=='male')]
#har query must be inside ()

# %%
df.loc[df['age'].isin([10,25])]
# Out:
#       pclass  survived                                             name  \
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 25         1         0                              Birnbaum, Mr. Jakob
# 26         1         1                          Bishop, Mr. Dickinson H
# 143        1         1                      Harder, Mr. George Achilles
# 144        1         1     Harder, Mrs. George Achilles (Dorothy Annan)
# 327        2         0                         Andrew, Mr. Frank Thomas
# 354        2         0                  Bryhl, Mr. Kurt Arnold Gottfrid
# 356        2         0                      Butler, Mr. Reginald Fenton
# 370        2         1                      Christy, Miss. Julie Rachel
# 393        2         0                             Denbury, Mr. Herbert
# 480        2         0           Laroche, Mr. Joseph Philippe Lemercier
# 555        2         0       Sedgwick, Mr. Charles Frederick Waddington
# ...

# %%
df[df.name.str.startswith('Mac')]
# Out:
#      pclass  survived                        name     sex   age  sibsp  parch  \
# 490       2         0           Mack, Mrs. (Mary)  female  57.0      0      0
# 983       3         0  MacKay, Mr. George William    male   NaN      0      0
#
#           ticket   fare cabin embarked boat  body                   home.dest
# 490  S.O./P.P. 3  10.50   E77        S  NaN  52.0  Southampton / New York, NY
# 983   C.A. 42795   7.55   NaN        S  NaN   NaN                         NaN

# %%
df[~df.name.str.startswith('Mac')]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.query('age==10')
# Out:
#       pclass  survived                          name     sex   age  sibsp  \
# 828        3         0   Goodwin, Miss. Jessie Allis  female  10.0      5
# 1141       3         0          Rice, Master. Albert    male  10.0      4
# 1207       3         0  Skoog, Master. Karl Thorsten    male  10.0      3
# 1265       3         0     Van Impe, Miss. Catharina  female  10.0      0
#
#       parch   ticket    fare cabin embarked boat  body  \
# 828       2  CA 2144  46.900   NaN        S  NaN   NaN
# 1141      1   382652  29.125   NaN        Q  NaN   NaN
# 1207      2   347088  27.900   NaN        S  NaN   NaN
# 1265      2   345773  24.150   NaN        S  NaN   NaN
#
#                                  home.dest  fare per age
# 828   Wiltshire, England Niagara Falls, NY        4.6900
# 1141                                   NaN        2.9125
# 1207                                   NaN        2.7900
# 1265                                   NaN        2.4150

# %%
df['age'].where(df['age']=='Male')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1304   NaN
# 1305   NaN
# 1306   NaN
# 1307   NaN
# 1308   NaN
# Name: age, Length: 1309, dtype: float64

# %%
df['fare per age'] = df['fare']/df['age']
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  fare per age
# ...
